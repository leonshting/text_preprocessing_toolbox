# %%
import networkx as nx

import sys
sys.path.insert(0, '/home/ALPHA/shtanko-la/Programming/preprocessing/')
sys.path.insert(0, '/home/ALPHA/shtanko-la/Programming/')


from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
# %matplotlib inline

# %%
from prod.dict_parsers.GraphDictParser import GraphDictParser

# %%
gdp = GraphDictParser(filename='../dicts/objects_dict_graph.json')

# %%
graph = nx.Graph(gdp.get_graph())

# %%
f, ax = plt.subplots(ncols=1, nrows=1, figsize=(15,15))
nx.draw(graph, label=True, node_size=0.2, with_labels=True, ax=ax)

# %%
gdp = GraphDictParser(filename='../dicts/actions_dict_graph.json')

# %%
graph = nx.Graph(gdp.get_graph())

# %%
f, ax = plt.subplots(ncols=1, nrows=1, figsize=(15,15))
nx.draw(graph, label=True, node_size=0.2, with_labels=True, ax=ax)

# %%
gdp = GraphDictParser(filename='../dicts/composed_entities_graph.json')

# %%
graph = nx.Graph(gdp.get_graph())

# %%
f, ax = plt.subplots(ncols=1, nrows=1, figsize=(15,15))
nx.draw(graph, label=True, node_size=0.2, with_labels=True, ax=ax)
